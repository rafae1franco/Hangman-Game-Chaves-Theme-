# %% [markdown]
# <a href="https://colab.research.google.com/github/rafae1franco/Hangman-Game-Chaves-Theme-/blob/main/dados_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Rafael Franco Lourençon

# %%
palavras = ["BARRIL", "CHURROS", "QUICO", "VIZINHANCA", "SEU MADRUGA"]

dicas = {
    "BARRIL": "Onde o personagem principal costuma se esconder.",
    "CHURROS": "Doce que o Chaves sempre tenta conseguir.",
    "QUICO": "Personagem mimado.",
    "VIZINHANCA": "Lugar onde todos moram.",
    "SEU MADRUGA": "Vive devendo aluguel."
}

# %%
# =========================
# HISTÓRICO DE PARTIDAS
# =========================
historico = []
